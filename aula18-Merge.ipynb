# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame(
    {
        "name": ["Oliver", "Emma", "Jack"],
        "age": [21, 24, 36],
        "education": ["BSc", "BA", "MSc"],
    }
)

df2 = pd.DataFrame(
    {
        "name": ["Jimmy", "Frank", "Sue", "Ava"],
        "age": [20, 18, 65, 40],
        "income": [40000, 0, 120000, 300000]
    }
)

df3 = pd.DataFrame(
    {
        "name": ["Emma", "Jack", "Mia"],
        "position": ["manager", "CFO", "analyst"],
        "salary": [78000, 160000, 56000],
        "education": ["BA", "PhD", "BSc"],
    }
)

# %%
df1
# Out:
#      name  age education
# 0  Oliver   21       BSc
# 1    Emma   24        BA
# 2    Jack   36       MSc

# %%
df2
# Out:
#     name  age  income
# 0  Jimmy   20   40000
# 1  Frank   18       0
# 2    Sue   65  120000
# 3    Ava   40  300000

# %%
df3
# Out:
#    name position  salary education
# 0  Emma  manager   78000        BA
# 1  Jack      CFO  160000       PhD
# 2   Mia  analyst   56000       BSc

# %% [markdown]
# # vertical combination

# %%
pd.concat([df1,df2])
# Out:
#      name  age education    income
# 0  Oliver   21       BSc       NaN
# 1    Emma   24        BA       NaN
# 2    Jack   36       MSc       NaN
# 0   Jimmy   20       NaN   40000.0
# 1   Frank   18       NaN       0.0
# 2     Sue   65       NaN  120000.0
# 3     Ava   40       NaN  300000.0

# %%
pd.concat([df1,df2], join="outer") # outer padrão
# Out:
#      name  age education    income
# 0  Oliver   21       BSc       NaN
# 1    Emma   24        BA       NaN
# 2    Jack   36       MSc       NaN
# 0   Jimmy   20       NaN   40000.0
# 1   Frank   18       NaN       0.0
# 2     Sue   65       NaN  120000.0
# 3     Ava   40       NaN  300000.0

# %%
pd.concat([df1,df2], join="inner") # somente colunas comuns
# Out:
#      name  age
# 0  Oliver   21
# 1    Emma   24
# 2    Jack   36
# 0   Jimmy   20
# 1   Frank   18
# 2     Sue   65
# 3     Ava   40

# %%
pd.concat([df1,df2], join="outer",sort=True) #ordem colunas
# Out:
#    age education    income    name
# 0   21       BSc       NaN  Oliver
# 1   24        BA       NaN    Emma
# 2   36       MSc       NaN    Jack
# 0   20       NaN   40000.0   Jimmy
# 1   18       NaN       0.0   Frank
# 2   65       NaN  120000.0     Sue
# 3   40       NaN  300000.0     Ava

# %% [markdown]
# # Horizontal merge/join

# %%
df1
# Out:
#      name  age education
# 0  Oliver   21       BSc
# 1    Emma   24        BA
# 2    Jack   36       MSc

# %%
df2
# Out:
#     name  age  income
# 0  Jimmy   20   40000
# 1  Frank   18       0
# 2    Sue   65  120000
# 3    Ava   40  300000

# %%
df1.merge(df3, on="name")
# Out:
#    name  age education_x position  salary education_y
# 0  Emma   24          BA  manager   78000          BA
# 1  Jack   36         MSc      CFO  160000         PhD

# %%
df1.merge(df3, on="name", how="inner")
# Out:
#    name  age education_x position  salary education_y
# 0  Emma   24          BA  manager   78000          BA
# 1  Jack   36         MSc      CFO  160000         PhD

# %%
df1.merge(df3, on="name", how="inner", suffixes=["_1", "_2"])
# Out:
#    name  age education_1 position  salary education_2
# 0  Emma   24          BA  manager   78000          BA
# 1  Jack   36         MSc      CFO  160000         PhD

# %%
# sintaxe alternativa
pd.merge(df1, df3, on="name", sort=False)
# Out:
#    name  age education_x position  salary education_y
# 0  Emma   24          BA  manager   78000          BA
# 1  Jack   36         MSc      CFO  160000         PhD

# %% [markdown]
# # outer join

# %%
df1
# Out:
#      name  age education
# 0  Oliver   21       BSc
# 1    Emma   24        BA
# 2    Jack   36       MSc

# %%
df3
# Out:
#    name position  salary education
# 0  Emma  manager   78000        BA
# 1  Jack      CFO  160000       PhD
# 2   Mia  analyst   56000       BSc

# %%
df1.merge(df3, on="name", how="outer")
# Out:
#      name   age education_x position    salary education_y
# 0  Oliver  21.0         BSc      NaN       NaN         NaN
# 1    Emma  24.0          BA  manager   78000.0          BA
# 2    Jack  36.0         MSc      CFO  160000.0         PhD
# 3     Mia   NaN         NaN  analyst   56000.0         BSc

# %% [markdown]
# # left outer join

# %%
df1.merge(df3, on="name", how="left")
# Out:
#      name  age education_x position    salary education_y
# 0  Oliver   21         BSc      NaN       NaN         NaN
# 1    Emma   24          BA  manager   78000.0          BA
# 2    Jack   36         MSc      CFO  160000.0         PhD

# %%
df1.merge(df3, on="name", how="right")
# Out:
#    name   age education_x position  salary education_y
# 0  Emma  24.0          BA  manager   78000          BA
# 1  Jack  36.0         MSc      CFO  160000         PhD
# 2   Mia   NaN         NaN  analyst   56000         BSc

# %% [markdown]
# # left_on right_on

# %%
df4 =df3.copy()

# %%
df4
# Out:
#    name position  salary education
# 0  Emma  manager   78000        BA
# 1  Jack      CFO  160000       PhD
# 2   Mia  analyst   56000       BSc

# %%
df4.rename({"name":"first_name"}, inplace=True,axis=1)

# %%
df4
# Out:
#   first_name position  salary education
# 0       Emma  manager   78000        BA
# 1       Jack      CFO  160000       PhD
# 2        Mia  analyst   56000       BSc

# %%
df1
# Out:
#      name  age education
# 0  Oliver   21       BSc
# 1    Emma   24        BA
# 2    Jack   36       MSc

# %%
df1.merge(df4, left_on="name", right_on="first_name", how="outer")
# Out:
#      name   age education_x first_name position    salary education_y
# 0  Oliver  21.0         BSc        NaN      NaN       NaN         NaN
# 1    Emma  24.0          BA       Emma  manager   78000.0          BA
# 2    Jack  36.0         MSc       Jack      CFO  160000.0         PhD
# 3     NaN   NaN         NaN        Mia  analyst   56000.0         BSc

# %% [markdown]
# # Case Study 1

# %%
BS =pd.read_parquet("data+files/SP500_balance_sheet.parquet")
IS =pd.read_parquet("data+files/SP500_income_statement.parquet")
companies = pd.read_parquet("data+files/SP500_constituents.parquet")

# %%
companies.sort_values("symbol")
# Out:
#     symbol                     name                  sector  \
# 308      A     Agilent Technologies             Health Care
# 149    AAL  American Airlines Group             Industrials
# 396   AAPL               Apple Inc.  Information Technology
# 173   ABBV                   AbbVie             Health Care
# 294    ABC        AmerisourceBergen             Health Care
# ..     ...                      ...                     ...
# 331    YUM              Yum! Brands  Consumer Discretionary
# 295    ZBH            Zimmer Biomet             Health Care
# 57    ZBRA       Zebra Technologies  Information Technology
# 296   ZION     Zions Bancorporation              Financials
# 170    ZTS                   Zoetis             Health Care
#
#                                       subSector                 headQuarter  \
# 308                       Health Care Equipment     Santa Clara, California
# 149                          Passenger Airlines           Fort Worth, Texas
# 396  Technology Hardware, Storage & Peripherals       Cupertino, California
# 173                             Pharmaceuticals     North Chicago, Illinois
# 294                    Health Care Distributors  Conshohocken, Pennsylvania
# ..                                          ...                         ...
# 331                                 Restaurants        Louisville, Kentucky
# 295                       Health Care Equipment             Warsaw, Indiana
# 57           Electronic Equipment & Instruments      Lincolnshire, Illinois
# 296                              Regional Banks        Salt Lake City, Utah
# 170                             Pharmaceuticals      Parsippany, New Jersey
#
#     dateFirstAdded      cik founded
# 308     2000-06-05  1090872    1999
# 149     2015-03-23     6201    1934
# 396     1982-11-30   320193    1977
# 173     2012-12-31  1551152    2013
# 294     2001-08-30  1140859    1985
# ..             ...      ...     ...
# 331     1997-10-06  1041061    1997
# 295     2001-08-07  1136869    1927
# 57      2019-12-23   877212    1969
# 296     2001-06-22   109380    1873
# 170     2013-06-21  1555280    1952
#
# [503 rows x 8 columns]

# %%
BS.sample(3)
# Out:
#        symbol       date      ddate reportedCurrency  uom        cik  \
# 505924    USB 2022-12-31 2022-12-31              USD  USD    36104.0
# 257490    DAL 2016-12-31 2016-12-31              USD  USD    27904.0
# 180033   ALLE 2016-12-31 2016-12-31              USD  USD  1579241.0
#
#         calendarYear period            companyName      fy  ...        PPENet  \
# 505924          2022     FY           U.S. Bancorp  2022.0  ...  3.858000e+09
# 257490          2016     FY  Delta Air Lines, Inc.  2016.0  ...  2.437500e+10
# 180033          2016     FY           Allegion plc  2016.0  ...  2.266000e+08
#
#         TotalReceivablesCurrent  RestrictedCashAndInvestmentsCurrent  \
# 505924             3.882130e+11                                  0.0
# 257490             2.064000e+09                                  0.0
# 180033             2.600000e+08                                  0.0
#
#         RestrictedCashAndInvestmentsNoncurrent  RetainedEarnings  \
# 505924                                     0.0      7.190100e+10
# 257490                                     0.0      7.903000e+09
# 180033                                     0.0      3.766000e+08
#
#         ShortTermBorrowings  ShortTermInvestments  StockholdersEquity  \
# 505924         3.121600e+10          1.616500e+11        5.076600e+10
# 257490         0.000000e+00          4.870000e+08        1.228700e+10
# 180033         0.000000e+00          0.000000e+00        1.133000e+08
#
#               Equity  TreasuryStockValue
# 505924  5.123200e+10        2.526900e+10
# 257490  1.228700e+10        2.740000e+08
# 180033  1.164000e+08        0.000000e+00
#
# [3 rows x 84 columns]

# %%
IS.sample(3)
# Out:
#        symbol       date      ddate reportedCurrency  uom       cik  \
# 318442    GIS 2014-05-25 2014-05-31              USD  USD   40704.0
# 436634    PHM 2013-12-31 2013-12-31              USD  USD  822416.0
# 208345    AVB 2013-12-31 2013-12-31              USD  USD  915912.0
#
#         calendarYear period                  companyName      fy  ...  \
# 318442          2014     FY          General Mills, Inc.  2014.0  ...
# 436634          2013     FY             PulteGroup, Inc.  2013.0  ...
# 208345          2013     FY  AvalonBay Communities, Inc.  2013.0  ...
#
#             Revenues  SellingAndMarketingExpense    SGAExpense  \
# 318442  0.000000e+00                         0.0  3.474300e+09
# 436634  5.679595e+09                         0.0  5.685000e+08
# 208345  1.462921e+09                         0.0  3.957300e+07
#
#         TangibleAssetImpairmentCharges  WaSharesDiluted  WaSharesBasic  \
# 318442                             0.0              0.0            0.0
# 436634                             0.0              0.0            0.0
# 208345                             0.0              0.0            0.0
#
#         cum_ratio  adj_factor  adj_EPSBasic  adj_EPSDiluted
# 318442  19.358742         1.0          2.90            2.83
# 436634  96.000000         1.0          6.79            6.72
# 208345   0.888889         1.0          2.78            2.78
#
# [3 rows x 75 columns]

# %%
# ROE = Net Income/average(total equity)
# ROA = NI/avg Total Assets

# %%
BS["Equity"]
# Out:
# 162586    5.185000e+09
# 162587    5.289000e+09
# 162588    5.301000e+09
# 162589    4.170000e+09
# 162590    4.246000e+09
#               ...
# 529284    2.185000e+09
# 529285    2.708000e+09
# 529286    3.773000e+09
# 529287    4.544000e+09
# 529288    4.403000e+09
# Name: Equity, Length: 5434, dtype: float64

# %%
IS["NI"]
# Out:
# 172117    1.153000e+09
# 172118    7.240000e+08
# 172119    5.040000e+08
# 172120    4.010000e+08
# 172121    4.620000e+08
#               ...
# 551486    1.428000e+09
# 551487    1.500000e+09
# 551488    1.638000e+09
# 551489    2.037000e+09
# 551490    2.114000e+09
# Name: NI, Length: 5455, dtype: float64

# %%
BS.head(5)
# Out:
#        symbol       date      ddate reportedCurrency  uom        cik  \
# 162586      A 2012-10-31 2012-10-31              USD  USD  1090872.0
# 162587      A 2013-10-31 2013-10-31              USD  USD  1090872.0
# 162588      A 2014-10-31 2014-10-31              USD  USD  1090872.0
# 162589      A 2015-10-31 2015-10-31              USD  USD  1090872.0
# 162590      A 2016-10-31 2016-10-31              USD  USD  1090872.0
#
#         calendarYear period                 companyName      fy  ...  \
# 162586          2012     FY  Agilent Technologies, Inc.  2012.0  ...
# 162587          2013     FY  Agilent Technologies, Inc.  2013.0  ...
# 162588          2014     FY  Agilent Technologies, Inc.  2014.0  ...
# 162589          2015     FY  Agilent Technologies, Inc.  2015.0  ...
# 162590          2016     FY  Agilent Technologies, Inc.  2016.0  ...
#
#               PPENet  TotalReceivablesCurrent  \
# 162586  1.164000e+09              923000000.0
# 162587  1.134000e+09              899000000.0
# 162588  1.101000e+09              983000000.0
# 162589  6.040000e+08              606000000.0
# 162590  6.390000e+08              631000000.0
#
#         RestrictedCashAndInvestmentsCurrent  \
# 162586                                  0.0
# 162587                                  0.0
# 162588                                  0.0
# 162589                          242000000.0
# 162590                                  0.0
#
#         RestrictedCashAndInvestmentsNoncurrent  RetainedEarnings  \
# 162586                                     0.0      5.505000e+09
# 162587                                     0.0      6.073000e+09
# 162588                                     0.0      6.466000e+09
# 162589                                     0.0      5.581000e+09
# 162590                                     0.0      6.089000e+09
#
#         ShortTermBorrowings  ShortTermInvestments  StockholdersEquity  \
# 162586          250000000.0                   0.0        5.182000e+09
# 162587                  0.0                   0.0        5.286000e+09
# 162588                  0.0                   0.0        5.298000e+09
# 162589                  0.0                   0.0        4.167000e+09
# 162590                  0.0                   0.0        4.243000e+09
#
#               Equity  TreasuryStockValue
# 162586  5.185000e+09        8.707000e+09
# 162587  5.289000e+09        9.607000e+09
# 162588  5.301000e+09        9.807000e+09
# 162589  4.170000e+09        1.007400e+10
# 162590  4.246000e+09        1.050800e+10
#
# [5 rows x 84 columns]

# %%
IS.head(5)
# Out:
#        symbol       date      ddate reportedCurrency  uom        cik  \
# 172117      A 2012-10-31 2012-10-31              USD  USD  1090872.0
# 172118      A 2013-10-31 2013-10-31              USD  USD  1090872.0
# 172119      A 2014-10-31 2014-10-31              USD  USD  1090872.0
# 172120      A 2015-10-31 2015-10-31              USD  USD  1090872.0
# 172121      A 2016-10-31 2016-10-31              USD  USD  1090872.0
#
#         calendarYear period                 companyName      fy  ...  \
# 172117          2012     FY  Agilent Technologies, Inc.  2012.0  ...
# 172118          2013     FY  Agilent Technologies, Inc.  2013.0  ...
# 172119          2014     FY  Agilent Technologies, Inc.  2014.0  ...
# 172120          2015     FY  Agilent Technologies, Inc.  2015.0  ...
# 172121          2016     FY  Agilent Technologies, Inc.  2016.0  ...
#
#             Revenues  SellingAndMarketingExpense    SGAExpense  \
# 172117  6.858000e+09                         0.0  1.817000e+09
# 172118  6.782000e+09                         0.0  1.880000e+09
# 172119  6.981000e+09                         0.0  2.043000e+09
# 172120  4.038000e+09                         0.0  1.189000e+09
# 172121  4.202000e+09                         0.0  1.253000e+09
#
#         TangibleAssetImpairmentCharges  WaSharesDiluted  WaSharesBasic  \
# 172117                             0.0              0.0            0.0
# 172118                             0.0              0.0            0.0
# 172119                             0.0              0.0            0.0
# 172120                             0.0              0.0            0.0
# 172121                             0.0              0.0            0.0
#
#         cum_ratio  adj_factor  adj_EPSBasic  adj_EPSDiluted
# 172117      1.000       1.398      2.367668        2.339056
# 172118      1.000       1.398      1.516452        1.502146
# 172119      1.000       1.398      1.080114        1.065808
# 172120      1.398       1.000      1.200000        1.200000
# 172121      1.398       1.000      1.420000        1.400000
#
# [5 rows x 75 columns]

# %%
# verificar se existe conbinacao de symbol e date
BS.duplicated(subset=["symbol","date"]).sum()
# Out:
# 0

# %%
IS.duplicated(subset=["symbol","date"]).sum()
# Out:
# 0

# %%
combined_data= BS.merge(IS, on=["symbol","date"], how="inner",suffixes=["","_is"])

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5433 entries, 0 to 5432
# Columns: 157 entries, symbol to adj_EPSDiluted
# dtypes: category(8), datetime64[ns](3), float64(141), int64(2), object(3)
# memory usage: 7.5+ MB

# %%
combined_data.columns
# Out:
# Index(['symbol', 'date', 'ddate', 'reportedCurrency', 'uom', 'cik',
#        'calendarYear', 'period', 'companyName', 'fy',
#        ...
#        'Revenues', 'SellingAndMarketingExpense', 'SGAExpense',
#        'TangibleAssetImpairmentCharges', 'WaSharesDiluted', 'WaSharesBasic',
#        'cum_ratio', 'adj_factor', 'adj_EPSBasic', 'adj_EPSDiluted'],
#       dtype='object', length=157)
