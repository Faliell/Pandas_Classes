# %%
import pandas as pd
import numpy as np

data =pd.read_csv("data+files/california_restaurants.csv")
df=pd.read_csv("data+files/example_1.csv", index_col="date")

# %%
df
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01     20.0      NaN     19.0
# 2023-01-02    465.0      NaN      NaN
# 2023-01-03      NaN     14.0     86.0
# 2023-01-04      NaN     25.0     19.0
# 2023-01-05     25.0      9.0      NaN
# 2023-01-06     75.0     75.0     19.0

# %%
df.Stock_A.isna()# retorna uma série booleana indicando True para os locais
#onde os valores estão ausentes (NaN) e False onde os valores estão presentes.
# Out:
# date
# 2023-01-01    False
# 2023-01-02    False
# 2023-01-03     True
# 2023-01-04     True
# 2023-01-05    False
# 2023-01-06    False
# Name: Stock_A, dtype: bool

# %%
df.loc[df.Stock_A.isna()]
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-03      NaN     14.0     86.0
# 2023-01-04      NaN     25.0     19.0

# %%
df.isna()
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01    False     True    False
# 2023-01-02    False     True     True
# 2023-01-03     True    False    False
# 2023-01-04     True    False    False
# 2023-01-05    False    False     True
# 2023-01-06    False    False    False

# %%
df[df.Stock_A.notna()]
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01     20.0      NaN     19.0
# 2023-01-02    465.0      NaN      NaN
# 2023-01-05     25.0      9.0      NaN
# 2023-01-06     75.0     75.0     19.0

# %%
# isnull(),notnull()funciona, mas não mais usado.

# %%
df
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01     20.0      NaN     19.0
# 2023-01-02    465.0      NaN      NaN
# 2023-01-03      NaN     14.0     86.0
# 2023-01-04      NaN     25.0     19.0
# 2023-01-05     25.0      9.0      NaN
# 2023-01-06     75.0     75.0     19.0

# %%
df.Stock_A + 100 #NaN não soma
# Out:
# date
# 2023-01-01    120.0
# 2023-01-02    565.0
# 2023-01-03      NaN
# 2023-01-04      NaN
# 2023-01-05    125.0
# 2023-01-06    175.0
# Name: Stock_A, dtype: float64

# %%
df.Stock_A + df.Stock_B # somar com NaN dá NaN
# Out:
# date
# 2023-01-01      NaN
# 2023-01-02      NaN
# 2023-01-03      NaN
# 2023-01-04      NaN
# 2023-01-05     34.0
# 2023-01-06    150.0
# dtype: float64

# %%
data.info() #comparar entries com valores para ver quantos NaN
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Yelp URL           1273 non-null   object
#  1   Name               1273 non-null   object
#  2   Street Address     1273 non-null   object
#  3   Zip Code           1259 non-null   float64
#  4   City               1263 non-null   object
#  5   State              1259 non-null   object
#  6   Price Range        1067 non-null   object
#  7   Phone              1196 non-null   object
#  8   Rating             1270 non-null   float64
#  9   Number of Reviews  1270 non-null   float64
#  10  Website            974 non-null    object
#  11  Menu Link          591 non-null    object
#  12  Image 1            1268 non-null   object
#  13  Image 2            1262 non-null   object
#  14  Image 3            1255 non-null   object
#  15  Category 1         1273 non-null   object
# ...

# %% [markdown]
# Abordagens para lidar com NaN

# %%
data.dropna() # apagar todos registos com NaN
# Out:
#                                                Yelp URL  \
# 2          https://www.yelp.com/biz/julies-cafe-chino-3
# 6     https://www.yelp.com/biz/sul-and-beans-rowland...
# 8     https://www.yelp.com/biz/ginkgo-katsu-diamond-bar
# 9     https://www.yelp.com/biz/king-coffee-usa-anahe...
# 10    https://www.yelp.com/biz/coffee-up-roastery-fu...
# ...                                                 ...
# 1252  https://www.yelp.com/biz/lazy-dog-restaurant-a...
# 1254  https://www.yelp.com/biz/banana-bay-restaurant...
# 1259   https://www.yelp.com/biz/green-tomato-grill-brea
# 1267  https://www.yelp.com/biz/snooze-an-a-m-eatery-...
# 1269         https://www.yelp.com/biz/yard-house-brea-4
#
#                            Name                Street Address  Zip Code  \
# 2                  Julie's Cafe            3746 Riverside Dr    91710.0
# 6                   Sul & Beans    1330 Fullerton Rd Unit 110   91748.0
# 8                  Ginkgo Katsu          1131 Brea Canyon Rd    91789.0
# ...

# %%
data.dropna(subset="Zip Code").shape # somente se houver NaN em Zio Code
# Out:
# (1259, 18)

# %%
data.dropna(subset=["Zip Code", "Name", "Price Range", "Rating"]).shape
# Out:
# (1055, 18)

# %%
data.dropna(subset=["Zip Code", "City"]).shape
# Out:
# (1259, 18)

# %%
data.dropna(subset=["Zip Code", "City"], how = "all").shape #how = "any" padrao
# somente apaga se as duas tiverem NaN
# Out:
# (1263, 18)

# %%
data.dropna(subset=["Zip Code", "City"], how = "all").dropna(
    subset=["Name", "Price Range", "Rating"]).shape
# Se as duas tiverem NaN e qualquer outra tiver NaN
# Out:
# (1059, 18)

# %%
df
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01     20.0      NaN     19.0
# 2023-01-02    465.0      NaN      NaN
# 2023-01-03      NaN     14.0     86.0
# 2023-01-04      NaN     25.0     19.0
# 2023-01-05     25.0      9.0      NaN
# 2023-01-06     75.0     75.0     19.0

# %%
df.dropna(axis=1) # apagar colula que tenha NaN
# Out:
# Empty DataFrame
# Columns: []
# Index: [2023-01-01, 2023-01-02, 2023-01-03, 2023-01-04, 2023-01-05, 2023-01-06]

# %%
# trocar NaN por 0
df.fillna(0)
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01     20.0      0.0     19.0
# 2023-01-02    465.0      0.0      0.0
# 2023-01-03      0.0     14.0     86.0
# 2023-01-04      0.0     25.0     19.0
# 2023-01-05     25.0      9.0      0.0
# 2023-01-06     75.0     75.0     19.0

# %%
df
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01     20.0      NaN     19.0
# 2023-01-02    465.0      NaN      NaN
# 2023-01-03      NaN     14.0     86.0
# 2023-01-04      NaN     25.0     19.0
# 2023-01-05     25.0      9.0      NaN
# 2023-01-06     75.0     75.0     19.0

# %%
#trocar o NaN pelo valor anterior - front fill
df.ffill()
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01     20.0      NaN     19.0
# 2023-01-02    465.0      NaN     19.0
# 2023-01-03    465.0     14.0     86.0
# 2023-01-04    465.0     25.0     19.0
# 2023-01-05     25.0      9.0     19.0
# 2023-01-06     75.0     75.0     19.0

# %%
df.bfill()#trocar pelo valor da frente- back fill
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01     20.0     14.0     19.0
# 2023-01-02    465.0     14.0     86.0
# 2023-01-03     25.0     14.0     86.0
# 2023-01-04     25.0     25.0     19.0
# 2023-01-05     25.0      9.0     19.0
# 2023-01-06     75.0     75.0     19.0

# %%
df.bfill(limit=1)
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01     20.0      NaN     19.0
# 2023-01-02    465.0     14.0     86.0
# 2023-01-03      NaN     14.0     86.0
# 2023-01-04     25.0     25.0     19.0
# 2023-01-05     25.0      9.0     19.0
# 2023-01-06     75.0     75.0     19.0

# %%
df.bfill(limit=1).ffill(limit=1)
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01     20.0      NaN     19.0
# 2023-01-02    465.0     14.0     86.0
# 2023-01-03    465.0     14.0     86.0
# 2023-01-04     25.0     25.0     19.0
# 2023-01-05     25.0      9.0     19.0
# 2023-01-06     75.0     75.0     19.0

# %%
df.fillna(df.mean()) #preencher com a media
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01    20.00    30.75    19.00
# 2023-01-02   465.00    30.75    35.75
# 2023-01-03   146.25    14.00    86.00
# 2023-01-04   146.25    25.00    19.00
# 2023-01-05    25.00     9.00    35.75
# 2023-01-06    75.00    75.00    19.00

# %%
df.mean()
# Out:
# Stock_A    146.25
# Stock_B     30.75
# Stock_C     35.75
# dtype: float64

# %%
df.mean(axis='columns')#media da row!!!
# Out:
# date
# 2023-01-01     19.500000
# 2023-01-02    465.000000
# 2023-01-03     50.000000
# 2023-01-04     22.000000
# 2023-01-05     17.000000
# 2023-01-06     56.333333
# dtype: float64

# %%
df.where(df.notna(),df.mean(axis=1),axis=0) # preencher com a media da linha
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01     20.0     19.5     19.0
# 2023-01-02    465.0    465.0    465.0
# 2023-01-03     50.0     14.0     86.0
# 2023-01-04     22.0     25.0     19.0
# 2023-01-05     25.0      9.0     17.0
# 2023-01-06     75.0     75.0     19.0

# %%
A = df.replace(np.nan, 0)
A
# Out:
#             Stock_A  Stock_B  Stock_C
# date
# 2023-01-01     20.0      0.0     19.0
# 2023-01-02    465.0      0.0      0.0
# 2023-01-03      0.0     14.0     86.0
# 2023-01-04      0.0     25.0     19.0
# 2023-01-05     25.0      9.0      0.0
# 2023-01-06     75.0     75.0     19.0

# %%
A["div"]=A.Stock_A/A.Stock_B # dividir por 0 passa a inf.
A
# Out:
#             Stock_A  Stock_B  Stock_C       div
# date
# 2023-01-01     20.0      0.0     19.0       inf
# 2023-01-02    465.0      0.0      0.0       inf
# 2023-01-03      0.0     14.0     86.0  0.000000
# 2023-01-04      0.0     25.0     19.0  0.000000
# 2023-01-05     25.0      9.0      0.0  2.777778
# 2023-01-06     75.0     75.0     19.0  1.000000

# %%
A.replace(np.inf,np.NaN) #inf nao é aceito em SQL por ex.
# Out:
#             Stock_A  Stock_B  Stock_C       div
# date
# 2023-01-01     20.0      0.0     19.0       NaN
# 2023-01-02    465.0      0.0      0.0       NaN
# 2023-01-03      0.0     14.0     86.0  0.000000
# 2023-01-04      0.0     25.0     19.0  0.000000
# 2023-01-05     25.0      9.0      0.0  2.777778
# 2023-01-06     75.0     75.0     19.0  1.000000

# %%
# interpolation

# %%
df.plot()
df.ffill().plot()
df.bfill().plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.interpolate().plot() #completa o NaN proporcional
# Out:
# <Axes: xlabel='date'>

# %%
df.interpolate()
# Out:
#                Stock_A  Stock_B  Stock_C
# date
# 2023-01-01   20.000000      NaN     19.0
# 2023-01-02  465.000000      NaN     52.5
# 2023-01-03  318.333333     14.0     86.0
# 2023-01-04  171.666667     25.0     19.0
# 2023-01-05   25.000000      9.0     19.0
# 2023-01-06   75.000000     75.0     19.0
